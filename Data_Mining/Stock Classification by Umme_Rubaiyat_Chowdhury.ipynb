# %% [markdown]
# # **Title: A Journey to Stock Classification**

# %% [markdown]
# # **Abstract**

# %% [markdown]
# A study of a stock market which is made up of thousands of investors and traders who have different ideas about the value and performance of a particular stock. Classify each stock company in the category of the stock is important before buying or selling a company's shares from or on a stock exchange, investors consider many factors beyond just the "category" of the company listed on the Stock Exchange (SE). As predicting how the stock market will perform is a hard task to do, discover the future value of company stock and other financial assets traded on an exchange are notfeasible generally
# to Classify it using a physically based process model. Recent developments in Machine
# Learning provide an alternative approach to classify each stock company accoring to our desire assumption. This study offers a
# description and comparison of some ML approaches which have proved to be useful in classify each stock company in the category of the stock moreover identify the stock companies that have the tendency to change the category. A comparative study establishes that the error made by the six ML
# models analyzed is less than a threshold value. The model with the best performance is
# the Random
# Forest, Logistic Regression compared to KNN Classification, Decision Tree, and Naive Bayes, Support vector machine, Artifical Nural Network. Compare these algorihms performance with different type of ensemble learning algorithms.

# %% [markdown]
# Key Words: Machine Learning Algorithm, KNN Classification, Decision Tree, Random
# Forest, Naive Bayes, support vector machine, Ensemble learning algorithms, Stock Exchange Classification

# %% [markdown]
# # **1. Introduction**

# %% [markdown]
# **Stock Market**

# %% [markdown]
# It is a place where shares of pubic listed companies are traded. The primary market is where companies float shares to the general public in an initial public offering (IPO) to raise capital.
#
#
# Once new securities have been sold in the primary market, they are traded in the secondary market—where one investor buys shares from another investor at the prevailing market price or at whatever price both the buyer and seller agree upon. The secondary market or the stock exchanges are regulated by the regulatory authority. In India, the secondary and primary markets are governed by the Security and Exchange Board of India (SEBI).
#
# A stock exchange facilitates stock brokers to trade company stocks and other securities. A stock may be bought or sold only if it is listed on an exchange. Thus, it is the meeting place of the stock buyers and sellers. Bangladesh's premier stock exchange is Dhaka Stock Exchange (DSE).

# %% [markdown]
# ### **Categories**

# %% [markdown]
# Categories in the context to financial markets are asset classes where an investor can invest. There are various categories to invest in such as debt instruments, equity instruments and a portfolio of both.
#
# Categories in context to mutual funds can be classified into equity fund, debt fund or hybrid funds with equity funds being classified by size (Large Cap Stocks, Mid Cap Stocks, Small Cap Stocks) and by investment styles like investing in a growth stock like a small company stock which possesses greater risk leading to greater returns.
#
# Other investment style includes investing in a value stock like large company stocks which are relatively less risky and hence provide lesser return. Similarly in the debt or fixed income instruments, the bonds can be categorized by maturity and credit rating risk. Hybrid funds can be a mix of equity and debt with a higher orientation towards any one commensurate with the investment objective.

# %% [markdown]
# # **Stock Categories of this study**

# %% [markdown]
# A- Category Companies
#
# Companies which are regular in holding the Annual General Meetings and have declared dividend at the rate of 10% or more in the last English calendar year.
#
# B- Category Companies
# Companies which are regular in holding the Annual General Meetings but have failed to declare dividend at least at the rate of 10% in the last English calendar year.
#
# N-Category Companies
# Newly listed companies except green-field companies which shall be transferred to other categories in accordance with their first dividend declaration and respective compliance after listing of their shares.
#
# Z-Category Companies
# Companies which have failed to hold the Annual General Meeting when due or have failed to declare any dividend based on annual performance or which are not in operation continuously for more than six months or whose accumulated loss after adjustment of revenue reserve, if any, exceeds its paid up capital.

# %% [markdown]
# There
# are some possible approaches to classify categories. One approach
# involves the study of the classification process to model the underlying features,
# However, this physically-based process modeling approach may not be feasible because:
#
#
#
# *   The stock market is notoriously volatile.
# *   he number of mutual dependencies with other areas of human life is huge.
# *   Taking all of these into account is virtually impossible for a human being.
#
# As, a machine doesn’t have to sleep or rest. It can work on a vast amount of data and analyze it much faster than any human being could. What a machine cannot do is make decisions based on the analysis without the specific input from humans. To deliver accuracy, ML algorithms need to be properly trained to understand what kind of patterns you’re looking for. The problem is, there may be too much randomness that interferes with patterns and throws off any analysis.
#
# Another approach to forecasting stock is based on the pattern recognition methodology
# which attempts to recognize stock patterns based on their feature.
#
# The aim of this study is to present a description and a comparison of some ML models that
# have been shown to be useful in classify category of stock data. The
# models analyzed here are the Logistic Regression, KNN Classification, Decision Tree, Random
# Forest, and Naive Bayes Algorithms, Support vector machine, ANN and Ensemble learning algorithms. Mean absolute percentage errors were used for the
# comparison of the goodness of fit criterion.

# %% [markdown]
# # **Literature Review**

# %% [markdown]
# Whereas a number of considers were attempted to get it the nature of the relationship between monetary improvement and financial development, as it were a number of included the part of stock markets within the financial improvement process.
#
# Different creators over the globe have explored capital showcase valuation from distinctive viewpoint.
#
# **Abdullah etal.( 2012**) anatomized whether capital request of Bangladesh was overrated. The study was grounded on17 laboriously traded companies in Dhaka Stock Exchange from 2006 to 2010. The study set up that the Stock Market was overrated and the companies under study were also hamstrung in managing costs.
#
#
# **Chowudhury & Abdullah( 2011)** in their study linked that lack of request regulation, lack of force of good shares, presence of syndicate, lack of fiscal knowledge helped the request indicator to jump over 8000 point during December 2011.
#
#
# **SaminaHaque and Murtaza Faruquee( 2013)** in their study of relating the influence of colorful abecedarian factors in determining the request price of shares in Dhaka Stock Exchange( DSE) tried to find out theco-relation between request price of the stocks and companies ’ performance, which includes earning per share( EPS), tip per share( DPS), return on equity( ROE), return on means( ROA), and the rate of fixed asset to total asset( FA/ TA). In the alternate member of the study, the request price of stocks under sample has been compared to abecedarian or natural price. This paper considers Net Asset Value( NAV) as ideal value of stock. The study depicts that the request price is veritably asleep toward fundamentals of companies and current request price is largely overvalued compared to the ideal value of stocks, which reinforces that fact that the impact of unauthorized information has a lesser influence in determining the price of stocks in medicinals and chemical assiduity in DSE.
#
# **Chowdhury & Chowdhury( 2010)** in their study anatomized the relationship between capital structure and firm value in Bangladesh. The study was grounded on secondary data of intimately listed companies in Dhaka Stock Exchange( DSE) and Chittagong Stock Exchange( CSE). The study set up a strongco-relation among current rate, operating influence, EPS, tip payout rate or share capital and stock price and concluded that by changing these parameters, a establishment may increase its value in the request.
#
# **Chen, Hong, and Stein( 2002)** anatomized the overvaluation generated by beliefs. The study concluded that the request overvaluation was caused by the investors ’ overconfidence.
# Indeed though a huge number of empirical studies have been accepted on geste of stock price in advanced requests, the focus on developing and arising requests has only begun in recent times.

# %% [markdown]
# # **Importance of this report**

# %% [markdown]
# Investors who purchase shares of various publicly traded companies mostly rely on SE authorities' category admission guidelines. SE holds shareholders' meetings (annual general meetings) and regularly declares dividends exceeding a minimum threshold (10% or more), or companies based on the event of success or non-declaration of dividends in the most recent English calendar year. classify. In addition to these few basic characteristics, the DSE must determine whether the company has been operating without interruption for more than his six months, or whether the accumulated loss after adjustment of retained earnings exceeds paid-in capital. Also consider whether
#
# It is therefore clearly seen that SE's classification rules for classifying listed companies are very primitive and inadequate for selecting characteristics to accurately predict a company's stock performance. In our view, this is not a sufficient guideline for a buyer or investor to assess the performance of our stock before considering a decision to purchase its stock. Note that none of these features are considered business logic for the classification of listed companies by the SE agency itself.
#
# This study sought to build a classification model for the categories of companies based on **nine new characteristics** or dependent variables, i. increase. 2. Stock net asset value (NAV); 3. Earnings per share (EPS); 4. Price Earnings Ratio, 5th Paid-in Capital per Share, 6th dir, Director Participation Rate, 7th Pub, General Participation Rate, 8th Inst, Institutional Investor Shareholding Rate, 8th Foreign Percentage of Foreign Ownership 9. Government Percentage Owned by the State. So rather than relying on his list of SE categories, he compared the category predictions of the classification model produced by this study to the DSE's listed categories to help investors make wise and safe stock-buying decisions. You can ensure safety by lowering the
#
# We also try to identify his SE-listed companies that tend to change categories. This type of forecast is very unique in its nature. This kind of truthful and accurate forecast will certainly help investors arm themselves with the tools to secure future purchases.

# %% [markdown]
# # **Research objectives**

# %% [markdown]
# *   Building a classification model to classify each stock company in the category of the stock
# *   To identify the stock companies that have the tendency to change the category
#
# *   Writing a scientific report after descriptive analysis of the collected data
# *   to find hidden information from the dataset and mention some advice to your client.
#
# *   compare the results obtained from ensample
# learning algorithms and single models

# %% [markdown]
# # **2. Methodology**

# %% [markdown]
# # **Statistical methods**

# %% [markdown]
# In this member we've used descriptive statistics that quantitatively describes or summarizes features from a collection of information. We've provied brief descriptive portions that have epitomized the given data set, which can be either a representation of the entire population or a sample of a population. Descriptive statistics are broken down into measures of central tendency and measures of variability( spread).
#
# Data Visualization
# For data visualization We've used matplotlib and Seaborn a Python visualization library grounded on matplotlib.
# We've used boxplot, different frequence distribution plots using histograms.

# %% [markdown]
# # Data Source

# %% [markdown]
# For this study, fundamental data of the stock companies was collected. The datasets consist of several stock company predictor (independent) variables and one target (dependent) variable, Outcome. Independent variables include the last price, net asset value (NAV) of the stock, Earnings Per Share (EPS), price-to-earnings (P/E) ratio of the stock, paid up capital per share, and so on. The total 374 company's data from 20 sector observations was
# computed and fitted in the ML methods. Missing values were estimated by the appropriate method.
#
# he outcome tested was Category, 258 tested positive and 500 tested negative. Therefore, there is one target (dependent) variable and 8 attributes.
#
# **Attribute Information:**
# *   CompanyName Name : of the stock company
# *   Sector: Sector name of the stock
# *   Category: Category of the stock
# *   Last price: Market price of the stock
# *   NAV: Net asset value (NAV) of the stock
# *   EPS: Earnings Per Share (EPS)
# *   p/e: Price-to-earnings (P/E) ratio of the stock
# *   Paid up: Paid-up capital per share
# *   Dir: Percentage of director holding share
# *   Pub: Percentage of public holding share
# *   Inst: Percentage of institute holding share
# *   Foreign: Percentages of foreign holding share
# *   Govt: Percentages of government holding share
#
# Python 3.8 was used for ML forecasting. A total of 374 company's data from 4 different categorys data were analyzed.
# Moreover, the software automatically split data into two groups; training and testing sets. The
# training set was used to train the models whereas the testing set was used to monitor or test the
# model performance.

# %%
pip install feature-engine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,roc_auc_score,roc_curve,confusion_matrix, accuracy_score 
from sklearn import tree
from sklearn.preprocessing import StandardScaler

#MISSING VALUE
from sklearn.linear_model import BayesianRidge

# Imputing with MICE using Bayes as estimator
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn import linear_model


from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

#Feature engine
from feature_engine.outliers import Winsorizer 
# importing ANN libraries
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras import regularizers
from keras import callbacks

# For visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# for Q-Q plots
import scipy.stats as stats

#For ml algorithms
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.ensemble import BaggingClassifier
from matplotlib import pyplot

#For Ensemble learning

from sklearn.pipeline import make_pipeline
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV

import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
# importing ANN libraries
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
#from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras import regularizers
from keras import callbacks

# %%
file_path="/content/StockData.csv"

#read the data and convert into DataFrame
df=pd.DataFrame(pd.read_csv(file_path, na_values=['#DIV/0!','#VALUE!']))

# %%
df.shape
# Out:
# (374, 13)

# %%
df.head(5)
# Out:
#   CompanyName Sector Category  Last Price    NAV    P/E   EPS   Paid up  \
# 0         NBL   Bank        A         9.8  18.92   8.31  1.18  30863.20
# 1    NRBCBANK   Bank        N        29.7  18.88  12.53  2.37    199.00
# 2      ABBANK   Bank        B        15.9  34.26  31.80  0.50   8159.37
# 3        IFIC   Bank        A        15.1  19.18  21.57  0.70  16397.70
# 4  RUPALIBANK   Bank        A        33.9  46.10  69.18  0.49   4340.69
#
#      Dir    Pub   Inst  Foreign   Govt
# 0  30.98  47.14  20.73     1.15   0.00
# 1  73.32  23.22   3.46     0.00   0.00
# 2  31.67  41.43  25.44     0.89   0.57
# 3   4.11  39.55  22.87     0.72  32.75
# 4   0.00   4.98   4.83     0.00  90.19

# %%
df.nunique()
# Out:
# CompanyName    374
# Sector          20
# Category         4
# Last Price     312
# NAV            336
# P/E            338
# EPS            280
# Paid up        342
# Dir            304
# Pub            355
# Inst           332
# Foreign        102
# Govt            22
# dtype: int64

# %%
df["Category"].unique()
# Out:
# array(['A', 'N', 'B', 'Z'], dtype=object)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# *   For data visualization We have used matplotlib and Seaborn a Python visualization library based on matplotlib.
#
# *   I have used Q-Q plot, boxplot, different frequency distributuion plots using histograms

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Two important aspects for the data preprocessing of this project –
#
#
#
# *   Basic NAN munging
# *   Label Encoding
# *   Standard Scaling

# %% [markdown]
# **Basic NAN munging**

# %% [markdown]
# After inspecting the number of missing values that are missing completely at randomlness than 20% of the total data elements,
# I replaced more than 5% of the NAN values with **mice imputation** algorithm and less than 5% of the NAN values was replaced by the mean of each column.

# %% [markdown]
# **Label Encoding**

# %% [markdown]
# to converting the labels into a numeric form so as to convert them into the machine-readable form

# %% [markdown]
# **Standard Scaling**

# %% [markdown]
# The Use of StandardScaler to remove the mean and scales of each feature to unit variance.

# %% [markdown]
# # **Data Pre-Processing**

# %% [markdown]
# Dropping features according to assignment instruction.

# %%
df= df.rename(columns={"P/E": "PEratio", "Last Price": "Last_Price", "Paid up": "Paid_up"})
df.head(5)
# Out:
#   CompanyName Sector Category  Last_Price    NAV  PEratio   EPS   Paid_up  \
# 0         NBL   Bank        A         9.8  18.92     8.31  1.18  30863.20
# 1    NRBCBANK   Bank        N        29.7  18.88    12.53  2.37    199.00
# 2      ABBANK   Bank        B        15.9  34.26    31.80  0.50   8159.37
# 3        IFIC   Bank        A        15.1  19.18    21.57  0.70  16397.70
# 4  RUPALIBANK   Bank        A        33.9  46.10    69.18  0.49   4340.69
#
#      Dir    Pub   Inst  Foreign   Govt
# 0  30.98  47.14  20.73     1.15   0.00
# 1  73.32  23.22   3.46     0.00   0.00
# 2  31.67  41.43  25.44     0.89   0.57
# 3   4.11  39.55  22.87     0.72  32.75
# 4   0.00   4.98   4.83     0.00  90.19

# %%
#Checking unique values of dependent features
print(df['Category'].value_counts())
# Out:
# A    270
# B     60
# Z     31
# N     13
# Name: Category, dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False, cbar=False)

# %%
# Checking columns list and missing values
df.isnull().sum()
# Out:
# CompanyName     0
# Sector          0
# Category        0
# Last_Price      0
# NAV             3
# PEratio        26
# EPS             0
# Paid_up         0
# Dir             0
# Pub             0
# Inst            0
# Foreign         0
# Govt            0
# dtype: int64

# %%
#Printing a concise summary of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CompanyName  374 non-null    object
#  1   Sector       374 non-null    object
#  2   Category     374 non-null    object
#  3   Last_Price   374 non-null    float64
#  4   NAV          371 non-null    float64
#  5   PEratio      348 non-null    float64
#  6   EPS          374 non-null    float64
#  7   Paid_up      374 non-null    float64
#  8   Dir          374 non-null    float64
#  9   Pub          374 non-null    float64
#  10  Inst         374 non-null    float64
#  11  Foreign      374 non-null    float64
#  12  Govt         374 non-null    float64
# dtypes: float64(10), object(3)
# memory usage: 38.1+ KB

# %%
df.describe()
# Out:
#         Last_Price         NAV      PEratio         EPS       Paid_up  \
# count   374.000000  371.000000   348.000000  374.000000    374.000000
# mean    123.026471   29.264963    57.341494    2.501818   2174.019920
# std     354.744582   77.801310   205.810167   21.737762   3285.313299
# min       7.100000 -865.970000 -1350.000000 -126.360000    199.000000
# 25%      20.325000   13.910000     8.580000    0.092500    525.500000
# 50%      39.600000   20.650000    20.655000    1.130000   1106.595000
# 75%      83.675000   36.910000    42.070000    2.210000   2005.950000
# max    4478.600000  357.750000  1775.000000  267.940000  30863.200000
#
#               Dir         Pub        Inst     Foreign        Govt
# count  374.000000  374.000000  374.000000  374.000000  374.000000
# mean    37.052960   34.756575   21.264484    1.241489    2.791578
# std     19.680636   18.343464   16.283813    4.686357   12.335236
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
# Find the variables with missing observations.

vars_with_na = [var for var in df.columns if df[var].isnull().mean() > 0]
vars_with_na
# Out:
# ['NAV', 'PEratio']

# %%
# Let's have a look at the values of the variables with
# missing data.

df[vars_with_na].head(6)
# Out:
#      NAV  PEratio
# 0  18.92     8.31
# 1  18.88    12.53
# 2  34.26    31.80
# 3  19.18    21.57
# 4  46.10    69.18
# 5  23.66     6.83

# %%
# Checking columns list and missing values
df['NAV'].isnull().sum()
# Out:
# 3

# %%
# Checking columns list and missing values
df['PEratio'].isnull().sum()
# Out:
# 26

# %%
#capture columns with less than 5% NA
cols_cca = [col for col in df.columns if df[col].isnull().mean() < 0.05]
cols_cca
# Out:
# ['CompanyName',
#  'Sector',
#  'Category',
#  'Last_Price',
#  'NAV',
#  'EPS',
#  'Paid_up',
#  'Dir',
#  'Pub',
#  'Inst',
#  'Foreign',
#  'Govt']

# %%
# Calculate the proportion of observations with complete
# cases: i.e., with values on all the variables.

# The method dropna() discards observations that contain
# any NA.

len(df.dropna(subset=cols_cca)) / len(df)
# Out:
# 0.9919786096256684

# %%
#Creating the complete case dataset
#where I remove observations with na in any columns
df_cca = df[cols_cca].dropna()
df.shape, df_cca.shape
# Out:
# ((374, 13), (371, 12))

# %%
fig, axes = plt.subplots(3, 3, figsize=(16,10))

Last_Price = df.Last_Price.hist(ax=axes[0][0],color='red').set_title('Last Price')
Last_Price = df.Last_Price.hist(ax=axes[0][0],color='blue',alpha=0.8).set_title('Last Price')

NAV = df.NAV.hist(ax=axes[0][1],color='red').set_title('NAV')
NAV = df.NAV.hist(ax=axes[0][1],color='blue',alpha=0.8).set_title('NAV')

EPS = df.EPS.hist(ax=axes[0][2],color='red').set_title('EPS')
EPS = df.EPS.hist(ax=axes[0][2],color='blue',alpha=0.8).set_title('EPS')

Paid_up = df.Paid_up.hist(ax=axes[1][0],color='red').set_title('Paid up')
Paid_up = df.Paid_up.hist(ax=axes[1][0],color='blue',alpha=0.8).set_title('Paid up')

Dir = df.Dir.hist(ax=axes[1][1],color='red').set_title('Dir')
Dir = df.Dir.hist(ax=axes[1][1],color='blue',alpha=0.8).set_title('Dir')

Pub = df.Pub.hist(ax=axes[1][2],color='red').set_title('Pub')
Pub = df.Pub.hist(ax=axes[1][2],color='blue',alpha=0.8).set_title('Pub')

Inst = df.Inst.hist(ax=axes[2][0],color='red').set_title('Inst')
Inst = df.Inst.hist(ax=axes[2][0],color='blue',alpha=0.8).set_title('Inst')

Foreign = df.Foreign.hist(ax=axes[2][1],color='red').set_title('Foreign')
Foreign = df.Foreign.hist(ax=axes[2][1],color='blue',alpha=0.8).set_title('Foreign')
Govt = df.Govt.hist(ax=axes[2][2],color='red').set_title('Govt')
Govt = df.Govt.hist(ax=axes[2][2],color='blue',alpha=0.8).set_title('Govt')

# %% [markdown]
# As we can see from the plots, the distribution of the numerical variables in the original and complete case datasets is very similar, which is what we expect from CCA when data is missing at random.
#
# In the next few cells, I will explore the distribution of categorical variables. To do so, I will evaluate the percentage of observations that show each of the unique categories

# %%
# The following function captures the percentage of observations
# per category in the original and complete case datasets
# and puts them together in a new dataframe.
def categorical_distribution(df, df_cca, variable):
  tmp = pd.concat(
      [
         # percentage of observations per category, original data
         df[variable].value_counts() / len(df),
         # percentage of observations per category, cca data
         df_cca[variable].value_counts() / len(df)
        
      ],
      axis=1)
  # add column names
  tmp.columns = ['original','cca']

  return tmp

# %%
#run the function in a categorical column
categorical_distribution(df, df_cca, 'Sector')
# Out:
#                              original       cca
# Textile                      0.155080  0.155080
# Insurance                    0.133690  0.125668
# Engineering                  0.112299  0.112299
# Mutual Funds                 0.096257  0.096257
# Bank                         0.080214  0.080214
# Pharmaceuticals & Chemicals  0.080214  0.080214
# Fuel & Power                 0.061497  0.061497
# Financial Institutions       0.058824  0.058824
# Food & Allied                0.053476  0.053476
# Miscellaneous                0.037433  0.037433
# IT Sector                    0.029412  0.029412
# Cement                       0.018717  0.018717
# Paper & Printing             0.016043  0.016043
# Tannery Industries           0.016043  0.016043
# Ceramics Sector              0.013369  0.013369
# Services & Real Estate       0.010695  0.010695
# Telecommunication            0.008021  0.008021
# Jute                         0.008021  0.008021
# Travel & Leisure             0.008021  0.008021
# ...

# %%
#run the function in a categorical column
categorical_distribution(df, df_cca, 'Category')
# Out:
#    original       cca
# A  0.721925  0.713904
# B  0.160428  0.160428
# Z  0.082888  0.082888
# N  0.034759  0.034759

# %% [markdown]
# As we can see from the output of the cells above, the distribution of houses in each of the categories is very similar in the original and complete case datasets, which is what is expected if the data is missing completely at random.

# %% [markdown]
# **MICE Imputer**

# %%
df_mice = df.filter(['PEratio'], axis=1).copy()

# Define MICE Imputer and fill missing values
mice_imputer = IterativeImputer(
    estimator=linear_model.BayesianRidge(), # the estimator to predict the NA
    n_nearest_features='mean', # how will NA be imputed in step 1
    max_iter=10, # number of cycles
    imputation_order='ascending', # the order in which to impute the variables
    #n_nearest_features=None, # whether to limit the number of predictors
    skip_complete=True, # whether to ignore variables without NA
    random_state=0,)

df_mice_imputed = pd.DataFrame(mice_imputer.fit_transform(df_mice), columns=df_mice.columns)

# %%
df_mice_imputed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PEratio  374 non-null    float64
# dtypes: float64(1)
# memory usage: 3.0 KB

# %%
df_mice_imputed.head(3)
# Out:
#    PEratio
# 0     8.31
# 1    12.53
# 2    31.80

# %%
#dropping the previous column from df Dataframe
df = df.drop(["PEratio"], axis = 1)
#joining the dataframe consisting imputed values with existing dataframe df
df= df.join(df_mice_imputed)
df.head()
# Out:
#   CompanyName Sector Category  Last_Price    NAV   EPS   Paid_up    Dir  \
# 0         NBL   Bank        A         9.8  18.92  1.18  30863.20  30.98
# 1    NRBCBANK   Bank        N        29.7  18.88  2.37    199.00  73.32
# 2      ABBANK   Bank        B        15.9  34.26  0.50   8159.37  31.67
# 3        IFIC   Bank        A        15.1  19.18  0.70  16397.70   4.11
# 4  RUPALIBANK   Bank        A        33.9  46.10  0.49   4340.69   0.00
#
#      Pub   Inst  Foreign   Govt  PEratio
# 0  47.14  20.73     1.15   0.00     8.31
# 1  23.22   3.46     0.00   0.00    12.53
# 2  41.43  25.44     0.89   0.57    31.80
# 3  39.55  22.87     0.72  32.75    21.57
# 4   4.98   4.83     0.00  90.19    69.18

# %%
# Basic nan munging. Fill each row's nans with the mean of the feature

df.NAV.fillna(df.NAV.mean(), inplace=True)

# %%
# Checking columns list and missing values
df.isnull().sum()
# Out:
# CompanyName    0
# Sector         0
# Category       0
# Last_Price     0
# NAV            0
# EPS            0
# Paid_up        0
# Dir            0
# Pub            0
# Inst           0
# Foreign        0
# Govt           0
# PEratio        0
# dtype: int64

# %% [markdown]
# **Checking Outliers**

# %%
# function to create histogram, Q-Q plot and
# boxplot.  


def diagnostic_plots(df, variable):
    # function takes a dataframe (df) and
    # the variable of interest as arguments

    # define figure size
    plt.figure(figsize=(16, 6))

    # histogram
    plt.subplot(1, 3, 1)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

    # Q-Q plot
    plt.subplot(1, 3, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    plt.ylabel('Variable quantiles')

    # boxplot
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

# %%
# let's find outliers in RM
diagnostic_plots(df, 'Last_Price')

# %%
# let's find outliers in RM
diagnostic_plots(df, 'NAV',)

# %%
# let's find outliers in RM
diagnostic_plots(df, 'EPS',)

# %%
# let's find outliers in RM
diagnostic_plots(df, 'Paid_up')

# %%
# let's find outliers in RM
diagnostic_plots(df, 'Dir',)

# %%
# let's find outliers in RM
diagnostic_plots(df, 'Pub')

# %%
# let's find outliers in RM
diagnostic_plots(df, 'Inst')

# %%
# let's find outliers in RM
diagnostic_plots(df,'Foreign',)

# %%
# let's find outliers in RM
diagnostic_plots(df,'Govt')

# %% [markdown]
# There are outliers almost all of the above variables. NAV, EPS, Dir, shows outliers in both tails, whereas Last_Price, Paid_up, Inst, Foreign, Govt are on the right tail.

# %% [markdown]
# **finding skeweness**

# %%
def find_skewed_boundaries(df, variable, distance):

    # Let's calculate the boundaries outside which sit the outliers
    # for skewed distributions

    # distance passed as an argument, gives us the option to
    # estimate 1.5 times or 3 times the IQR to calculate
    # the boundaries.

    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

    lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
    upper_boundary = df[variable].quantile(0.75) + (IQR * distance)

    return upper_boundary, lower_boundary

# %%
# find limits for NAV

NAV_upper_limit, NAV_lower_limit = find_skewed_boundaries(df, 'NAV', 1.5)
NAV_upper_limit, NAV_lower_limit
# Out:
# (71.26625, -20.48375)

# %%
# find limits for EPS

EPS_upper_limit, EPS_lower_limit = find_skewed_boundaries(df, 'EPS', 1.5)
EPS_upper_limit, EPS_lower_limit
# Out:
# (5.38625, -3.0837500000000007)

# %%
# find limits for Dir

Dir_upper_limit, Dir_lower_limit = find_skewed_boundaries(df, 'Dir', 1.5)
Dir_upper_limit, Dir_lower_limit
# Out:
# (79.23124999999999, 0.4612500000000068)

# %%
# find limits for Last_Price

Last_Price_upper_limit, Last_Price_lower_limit = find_skewed_boundaries(df, 'Last_Price', 1.5)
Last_Price_upper_limit, Last_Price_lower_limit
# Out:
# (178.7, -74.69999999999999)

# %%
# find limits for Paid_up

Paid_up_upper_limit, Paid_up_lower_limit = find_skewed_boundaries(df, 'Paid_up', 1.5)
Paid_up_upper_limit, Paid_up_lower_limit
# Out:
# (4226.625, -1695.1749999999997)

# %%
# find limits for Inst

Inst_upper_limit, Inst_lower_limit = find_skewed_boundaries(df, 'Inst', 1.5)
Inst_upper_limit, Inst_lower_limit
# Out:
# (51.962500000000006, -15.3175)

# %%
# find limits for Foreign

Foreign_upper_limit, Foreign_lower_limit = find_skewed_boundaries(df, 'Foreign', 1.5)
Foreign_upper_limit, Foreign_lower_limit
# Out:
# (0.525, -0.315)

# %%
# find limits for Govt

Govt_upper_limit, Govt_lower_limit = find_skewed_boundaries(df, 'Govt', 1.5)
Govt_upper_limit, Govt_lower_limit
# Out:
# (0.0, 0.0)

# %%
# replacing the outliers by the maximum and minimum limit

df['NAV']= np.where(df['NAV'] > NAV_upper_limit, NAV_upper_limit,
                       np.where(df['NAV'] < NAV_lower_limit, NAV_lower_limit, df['NAV']))

# %%
# replacing the outliers by the maximum and minimum limit

df['EPS']= np.where(df['EPS'] > EPS_upper_limit, EPS_upper_limit,
                       np.where(df['EPS'] < EPS_lower_limit, EPS_lower_limit, df['EPS']))

# %%
# replacing the outliers by the maximum and minimum limit

df['Dir']= np.where(df['Dir'] > Dir_upper_limit, Dir_upper_limit,
                       np.where(df['Dir'] < Dir_lower_limit, Dir_lower_limit, df['Dir']))

# %%
# replacing the outliers by the maximum and minimum limit

df['Last_Price']= np.where(df['Last_Price'] > Last_Price_upper_limit, Last_Price_upper_limit,
                       np.where(df['Last_Price'] < Last_Price_lower_limit, Last_Price_lower_limit, df['Last_Price']))

# %%
# replacing the outliers by the maximum and minimum limit

df['Paid_up']= np.where(df['Paid_up'] > Paid_up_upper_limit, Paid_up_upper_limit,
                       np.where(df['Paid_up'] < Paid_up_lower_limit, Paid_up_lower_limit, df['Paid_up']))

# %%
# replacing the outliers by the maximum and minimum limit

df['Inst']= np.where(df['Inst'] > Inst_upper_limit, Inst_upper_limit,
                       np.where(df['Inst'] < Inst_lower_limit, Inst_lower_limit, df['Inst']))

# %%
# replacing the outliers by the maximum and minimum limit

df['Foreign']= np.where(df['Foreign'] > Foreign_upper_limit, Foreign_upper_limit,
                       np.where(df['Foreign'] < Foreign_lower_limit, Foreign_lower_limit, df['Foreign']))

# %%
# replacing the outliers by the maximum and minimum limit

df['Govt']= np.where(df['Govt'] > NAV_upper_limit, NAV_upper_limit,
                       np.where(df['Govt'] < NAV_lower_limit, NAV_lower_limit, df['Govt']))

# %%
# exploring outliers in the trimmed dataset
# for Last_Price we see much less outliers as in the original dataset
diagnostic_plots(df, 'Last_Price')

# %%
 
diagnostic_plots(df, 'NAV')

# %%
 
diagnostic_plots(df, 'EPS')

# %%
diagnostic_plots(df, 'Paid_up')

# %%
diagnostic_plots(df, 'Dir')

# %%
diagnostic_plots(df, 'Inst')

# %%
diagnostic_plots(df,'Foreign',)

# %%
diagnostic_plots(df,'Govt')

# %% [markdown]
# We can see that the outliers are gone, but the variable distribution was distorted quite a bit.

# %% [markdown]
# # **3. Data Analysis and Results**

# %% [markdown]
# # **Various Plotting Analysis**

# %%
 # Now I have tried to  first review the 'Category' relation with other numerical variables
fig, axarr = plt.subplots(4, 2,figsize=(40, 24))
sns.barplot(x='Category', y = 'Last_Price',data = df, ax=axarr[0][0])
sns.barplot(x='Category', y = 'NAV',data = df, ax=axarr[0][1])
sns.barplot(x='Category', y = 'EPS',data = df, ax=axarr[1][0])
sns.barplot(x='Category', y = 'Paid_up',data = df, ax=axarr[1][1])
sns.barplot(x='Category', y = 'Dir',data = df, ax=axarr[2][0])
sns.barplot(x='Category', y='Inst',data = df, ax=axarr[2][1])
sns.barplot(x='Category', y='Foreign',data = df, ax=axarr[3][0])
sns.barplot(x='Category', y='Govt',data = df, ax=axarr[3][1])

# %% [markdown]
# # **Correlation Matrix**

# %%
#Checking correlation matrix
correlarions_matrix = df.corr().round(2)

# %%
#Plotting the heatmap
sns.heatmap(data= correlarions_matrix,  annot= True)

# %% [markdown]
# # Descriptive **Analysis**

# %%
print("Category distribution of DSE:\n",df["Category"].value_counts(),"\n")
print("Category proportion of DSE:\n",df["Category"].value_counts(normalize=True))
# Out:
# Category distribution of DSE:
#  A    270
# B     60
# Z     31
# N     13
# Name: Category, dtype: int64
#
# Category proportion of DSE:
#  A    0.721925
# B    0.160428
# Z    0.082888
# N    0.034759
# Name: Category, dtype: float64

# %% [markdown]
#
#
# *   On an average 'Z' category compnies do not have any Net Asset Value NAV. Instead, their average net liability is almost of worth 61 hundred thousand BDT
# *   Earnings Per Share, EPS is negative for botht the 'B' and 'Z' category companies.
#
# *   Average Paid up capital of 'Z' category compnies are less than half of that of category A companies

# %%
print("Grouped mean of Last Price (BDT):\n", 
      df.groupby("Category")["Last Price"].mean(),"\n")
print("Grouped mean of NAV (mn BDT):\n",
      df.groupby("Category")["NAV"].mean(),"\n")
print("\nGrouped mean of Price-to-earnings (P/E) ratio of the stock:\n",
      df.groupby("Category")["P/E"].mean(),"\n")
print("Grouped mean of Earnings Per Share (EPS):\n",
      df.groupby("Category")["EPS"].mean(),"\n")
ex = sns.barplot('Category', 'EPS', data=df, ci=False)
ex.set_ylabel('Earning per Share - EPS')
ex.set_title('Categorywise distribution of EPS)')
plt.show()

print("\nCategorywise Grouped mean of Paid up Capital (mn BDT): \n",
      df.groupby("Category")["Paid up"].mean(),"\n")
sns.barplot('Category', 'Paid up', data=df, ci=False)
plt.show()

print("\nSectorwise Grouped mean of Paid up Capital (mn BDT): \n",
      df.groupby("Sector")["Paid up"].mean(),"\n")
grp_order = df.groupby('Sector')["Paid up"].agg('mean').sort_values(ascending=False).index
bx = sns.barplot('Sector', "Paid up", data=df, 
                 estimator = np.mean, order=grp_order,ci=False)
bx.set_xticklabels(bx.get_xticklabels(), 
                   rotation=90, horizontalalignment='right')
bx.set_ylabel('Paid up Capital (mn BDT)')
bx.set_title('\nSectorwise Distribution of grouped mean of Paid up Capital (mn BDT)\n')
# Out:
# Grouped mean of Last Price (BDT):
#  Category
# A    151.797407
# B     46.303333
# N     56.815385
# Z     48.703226
# Name: Last Price, dtype: float64
#
# Grouped mean of NAV (mn BDT):
#  Category
# A    41.918015
# B    21.270833
# N     7.369231
# Z   -55.059958
# Name: NAV, dtype: float64
#
#
# Grouped mean of Price-to-earnings (P/E) ratio of the stock:
#  Category
# A     48.223745
# B    119.038644
# N     49.402500
# Z      9.384615
# Name: P/E, dtype: float64
#
# Grouped mean of Earnings Per Share (EPS):
#  Category
# A    5.170196
# B   -2.709033
# N    0.660769
# Z   -9.881323
# Name: EPS, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
class color:
   gray ='\033[30m'       
   greenv = '\033[32m'
   yellowl = '\033[33m'
   yellow = '\033[93m'
   skyblue = '\033[34m'
   purple = '\033[35m'
   darkcyan = '\033[36m'
   white = '\033[37m'
   red = '\033[91m'
   green = '\033[92m'
   blue = '\033[94m'
   magenta = '\033[95m'
   cyan = '\033[96m'
   
  # Format 
   bold = '\033[1m'
   italic = '\033[3m'
   underline = '\033[4m'

  # Text Reset
   dflt = '\033[0m'

# %%
print(color.yellowl + "Sector distribution:\n" 
      + color.dflt, df["Sector"].value_counts(),"\n")

import seaborn as sns
sns.set_style("darkgrid")
ax = sns.countplot(x='Sector', data=df,  order=df.Sector.value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, horizontalalignment='right')
ax.set_title('Sectorwise company distribution  ')
plt.show()

print(color.purple + color.bold + "Sector proportion: \n" + color.dflt, 
      df["Sector"].value_counts(normalize=True))
print(color.bold + "\nTotal Sectors:" + color.dflt + color.green, 
      len(df.Sector.unique()), color.dflt)
# Out:
# Sector distribution:
#  Textile                        58
# Insurance                      50
# Engineering                    42
# Mutual Funds                   36
# Bank                           30
# Pharmaceuticals & Chemicals    30
# Fuel & Power                   23
# Financial Institutions         22
# Food & Allied                  20
# Miscellaneous                  14
# IT Sector                      11
# Cement                          7
# Paper & Printing                6
# Tannery Industries              6
# Ceramics Sector                 5
# Services & Real Estate          4
# Telecommunication               3
# Jute                            3
# Travel & Leisure                3
# Corporate Bond                  1
# Name: Sector, dtype: int64
# Sector proportion:
#  Textile                        0.155080
# Insurance                      0.133690
# Engineering                    0.112299
# Mutual Funds                   0.096257
# ...

# %% [markdown]
# **Categorywise Multiple grouped summaries**

# %%
print("Grouped summary of Last Price (BDT):\n", df.groupby("Category")["Last Price"].agg([min, max]),"\n")
print("Grouped summary of NAV (mn BDT):\n",df.groupby("Category")["NAV"].agg([min, max]),"\n")
print("Grouped summary of Price-to-earnings (P/E) ratio of the stock:\n",df.groupby("Category")["P/E"].agg([min, max]),"\n")
print("Grouped summary of Earnings Per Share (EPS):\n",df.groupby("Category")["EPS"].agg([min, max]),"\n")
print("Grouped summary of Paid up Capital (mn BDT):\n",df.groupby("Category")["Paid up"].agg([min, max]),"\n")
# Out:
# Grouped summary of Last Price (BDT):
#             min     max
# Category
# A          9.3  4478.6
# B          9.8   247.0
# N         29.7   122.3
# Z          7.1   234.0
#
# Grouped summary of NAV (mn BDT):
#               min     max
# Category
# A           2.00  357.75
# B           2.00  133.00
# N           2.00   22.98
# Z        -865.97   94.45
#
# Grouped summary of Price-to-earnings (P/E) ratio of the stock:
#                min      max
# Category
# A        -1350.00  1775.00
# B         -500.00  1690.00
# N           12.53   142.73
# Z         -285.00   870.00
#
# Grouped summary of Earnings Per Share (EPS):
#               min     max
# Category
# A         -55.71  267.94
# B        -126.36    4.12
# N           0.00    4.58
# Z        -121.38    3.33
#
# Grouped summary of Paid up Capital (mn BDT):
#               min       max
# Category
# A         199.00  30863.20
# B         248.03  10220.10
# N         199.00    199.00
# Z         199.00   6846.02

# %% [markdown]
# **Grouping by multiple variables**

# %%
df_gmv = df.groupby(["Category", "Sector"])[["Last Price", "NAV", "EPS", "Paid up","Pub","Inst","Foreign"]].mean()
df_gmv.sort_values(['Category','NAV',"Pub","Inst","Foreign"],ascending=[True,False,False,False,False])
# Out:
#                                        Last Price         NAV        EPS  \
# Category Sector
# A        Paper & Printing              180.100000  177.715000   1.625000
#          Jute                          392.400000  155.595000   5.975000
#          Fuel & Power                  234.572222   87.026111  11.201667
#          Miscellaneous                 328.887500   80.410000   7.083750
#          Food & Allied                 510.210000   72.946000   5.723000
#          Tannery Industries            267.300000   68.812500  84.562500
#          Pharmaceuticals & Chemicals   528.960870   67.294783  16.403478
#          Travel & Leisure               35.000000   57.275000   0.500000
#          Engineering                   161.813333   43.129000   1.013903
#          Services & Real Estate         48.975000   42.542500   1.317500
#          Cement                        126.900000   40.920000   2.106667
#          Ceramics Sector                82.500000   39.955000   0.615000
# ...

# %% [markdown]
# **Sort by stock holding of Public**

# %% [markdown]
# The following result shows that percentage (%) of public holding share is highest in 'A' category companies from Jute sectors. On an average, general investors hold 64.25% of the share stocks of 'A' category companies fromm this sector.
#
# However, in case pf 'B' category companies, percentage (%) of public holding share is highest in Food & Allied sector.

# %%
df_gmv2 = df.groupby(["Category", "Sector"])[["Pub","Inst","Foreign"]].mean()
df_gmv2.sort_values(['Category',"Pub","Inst","Foreign"],
                    ascending=[True,False,False,False])
# Out:
#                                             Pub       Inst   Foreign
# Category Sector
# A        Jute                         64.250000   2.815000  0.000000
#          Insurance                    39.893750  18.361250  0.269750
#          Engineering                  35.939333  19.105667  0.825000
#          Miscellaneous                34.171250  14.791250  0.030000
#          Textile                      33.720303  19.783333  2.574242
#          Tannery Industries           33.450000  25.420000  0.477500
#          Bank                         32.819259  21.847037  3.050370
#          Services & Real Estate       32.807500  19.110000  0.965000
#          Pharmaceuticals & Chemicals  32.035217  18.133913  3.740870
#          Food & Allied                30.747000  10.907000  5.052000
#          IT Sector                    29.851429  28.661429  2.620000
#          Financial Institutions       26.323846  21.153846  3.430000
# ...

# %% [markdown]
# **Sort by Institute holding shares**

# %% [markdown]
# *   Institutes mostly hold lion shares (more than 50% stock) of Corporate Bond sector of 'A' category companies followed by Mutual Funds sector of the same cateogory companies.
# *   Institutes also hold a significant percentage of stock (more than 25%) in Travel & Lesiure, Bank and IT Sector respectively from 'B' category companies.
#
# *   Surprisingly institutions are holding a significant percentage of stock (more than 25%) in Financial
# Institutions, Insurance and Jute sectors respectively all of which are from risky 'Z' category companies.

# %% [markdown]
# #**Label Encoding on Categorical Values**

# %% [markdown]
# Converting the Probable Categorical value into binary form

# %%
#converting the probable categorical value into binary form for ease of operation
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder() 
df['Sector'] = lb.fit_transform(df['Sector'])
print(df['Sector'])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 369    18
# 370    18
# 371    19
# 372    19
# 373    19
# Name: Sector, Length: 374, dtype: int64

# %%
print(pd.unique(df['Category']))
# Out:
# ['A' 'N' 'B' 'Z']

# %%
#converting the probable categorical value into binary form for ease of operation
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder() 
df['Category'] = lb.fit_transform(df['Category'])
print(df['Category'])
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
#       ..
# 369    3
# 370    0
# 371    0
# 372    1
# 373    0
# Name: Category, Length: 374, dtype: int64

# %%
lb.transform(['A', 'N', 'B', 'Z'])
# Out:
# array([0, 2, 1, 3])

# %%
X = pd.DataFrame(df.loc[:,["Last_Price", "NAV", "EPS", "Pub","Paid_up", "Dir", "Inst", "Foreign", "Govt"]])
y = pd.DataFrame(df.loc[:,["Category"]])

# %%
#making X
np.random.seed(42)
X_shadow = X.apply(np.random.permutation)
X_shadow.columns = ['shadow_'+ feat for feat in X.columns]
X_boruta = pd.concat([X,X_shadow], axis =1)

# %% [markdown]
# # **Feature Selection Algorithm (Boruta)**

# %%
# !pip install boruta
from boruta import BorutaPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 56 kB 3.1 MB/s
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor(max_depth = 5, random_state = 42)
forest.fit(X_boruta, y)

feat_imp_X = forest.feature_importances_[:len(X.columns)]
feat_imp_shadow = forest.feature_importances_[len(X.columns)]

hits = feat_imp_X > feat_imp_shadow.max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.

# %%
hits= np.zeros((len(X.columns)))

for iter_ in range(20):
  np.random.seed(iter_)
  X_shadow = X.apply(np.random.permutation)
  X_boruta = pd.concat([X,X_shadow], axis= 1)

  forest = RandomForestRegressor(max_depth= 5, random_state= 42)
  forest.fit(X_boruta, y)

  feat_imp_X = forest.feature_importances_[:len(X.columns)]
  feat_imp_shadow = forest.feature_importances_[len(X.columns)]

  hits += (feat_imp_X > feat_imp_shadow.max())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %%
###initialize Boruta
forest = RandomForestRegressor(
n_jobs = -1,
max_depth = 5
)
boruta = BorutaPy(
estimator = forest,
n_estimators = 'auto',
max_iter = 100 # number of trials to perform
)
### fit Boruta (it accepts np.array, not pd.DataFrame)
boruta.fit(np.array(X), np.array(y))
### print results
green_area = X.columns[boruta.support_].to_list()
blue_area = X.columns[boruta.support_weak_].to_list()
print('features in the green area:', green_area)
print('features in the blue area:', blue_area)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/boruta/boruta_py.py:384: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator.fit(X, y)
# /usr/local/lib/python3.7/dist-packages/boruta/boruta_py.py:384: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.estimator.fit(X, y)
# /usr/local/lib/python3.7/dist-packages/boruta/boruta_py.py:384: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ...

# %% [markdown]
# So, the important features are 'Last_Price', 'NAV', 'EPS', 'Pub', 'Paid_up', 'Inst'

# %%
df_imp  = pd.DataFrame(df.loc[:,["Last_Price", "NAV", "EPS", "Pub","Paid_up", "Inst"]])
df_imp.head(5)
# Out:
#    Last_Price    NAV   EPS    Pub   Paid_up   Inst
# 0         9.8  18.92  1.18  47.14  4226.625  20.73
# 1        29.7  18.88  2.37  23.22   199.000   3.46
# 2        15.9  34.26  0.50  41.43  4226.625  25.44
# 3        15.1  19.18  0.70  39.55  4226.625  22.87
# 4        33.9  46.10  0.49   4.98  4226.625   4.83

# %% [markdown]
# # **Standard Scaling**

# %%
#Here, I used StandardScaler to remove the mean and scales each feature to unit variance.
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled_df = pd.DataFrame(StandardScaler().fit_transform(df_imp),columns = df_imp.columns)
scaled_df.head()
# Out:
#    Last_Price       NAV       EPS       Pub   Paid_up      Inst
# 0   -0.946013 -0.375416 -0.057398  0.675991  2.068127  0.027589
# 1   -0.592010 -0.377288  0.504493 -0.629763 -1.001253 -1.223303
# 2   -0.837500  0.342640 -0.378478  0.364291  2.068127  0.368741
# 3   -0.851731 -0.363245 -0.284043  0.261665  2.068127  0.182592
# 4   -0.517296  0.896863 -0.383200 -1.625454  2.068127 -1.124072

# %%
df1  = pd.DataFrame(df.loc[:,["Category"]])
df1.head(5)
# Out:
#    Category
# 0         0
# 1         2
# 2         1
# 3         0
# 4         0

# %%
df= scaled_df.join(df1)
df.head(5)
# Out:
#    Last_Price       NAV       EPS       Pub   Paid_up      Inst  Category
# 0   -0.946013 -0.375416 -0.057398  0.675991  2.068127  0.027589         0
# 1   -0.592010 -0.377288  0.504493 -0.629763 -1.001253 -1.223303         2
# 2   -0.837500  0.342640 -0.378478  0.364291  2.068127  0.368741         1
# 3   -0.851731 -0.363245 -0.284043  0.261665  2.068127  0.182592         0
# 4   -0.517296  0.896863 -0.383200 -1.625454  2.068127 -1.124072         0

# %%
#Choossing the independent variable X and the dependent variable Y
X = df.iloc[:, ] 
y = df.iloc[:, -1]

# %%
X[0:6]
# Out:
#    Last_Price       NAV       EPS       Pub   Paid_up      Inst  Category
# 0   -0.946013 -0.375416 -0.057398  0.675991  2.068127  0.027589         0
# 1   -0.592010 -0.377288  0.504493 -0.629763 -1.001253 -1.223303         2
# 2   -0.837500  0.342640 -0.378478  0.364291  2.068127  0.368741         1
# 3   -0.851731 -0.363245 -0.284043  0.261665  2.068127  0.182592         0
# 4   -0.517296  0.896863 -0.383200 -1.625454  2.068127 -1.124072         0
# 5   -0.878415 -0.153539  0.325065 -0.010185  2.068127  0.405681         0

# %%
y[0:5]
# Out:
# 0    0
# 1    2
# 2    1
# 3    0
# 4    0
# Name: Category, dtype: int64

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # **Classification Approach of Data Mining**

# %% [markdown]
# For building the classification models we have used the following algorithms of data mining:
#
# **Logistic Regression:** In statistics, the logistic model is used to model the probability of a certain class or event. This can be extended to model several classes of events.
#
# **KNN (k-nearest neighbors algorithm):** In statistics, the k-nearest neighbors algorithm is a non-parametric classification method. It is used for classification and regression.
#
#
# **A Decision Tree** is a decision support tool that uses a tree-like model of decisions and their possible consequences, including chance event outcomes
#
# **Random forests or random decision forests** is an ensemble learning method for classification, regression and other tasks that operates by constructing a multitude of decision trees at training time.
#
# **Naive Bayes:** In statistics, naive Bayes classifiers are a family of simple "probabilistic classifiers" based on applying Bayes' theorem with strong (naive) independence assumptions between the features (see Bayes classifier).
#
# **SVM (Support vector machine):** In machine learning, support-vector machines are supervised learning models with associated learning algorithms that analyze data for classification and regression analysis.
# Ensemble learning: A process in which decisions from multiple machine learning models are combined to reduce errors and improve prediction when compared to a single ML model
#
#
# **Parallel Ensemble Learning** - I have applied the Bagging methods of avaraging method type as Logistic Regression as our Base Learner
# Sequential Ensemple Learning - I have applied the xgboost of boosting method type as SVM as our Base Learner
#
# **Artificial neural networks (ANNs):** - is a computational model that consists of several processing elements that receive inputs and deliver outputs based on their predefined activation functions
#
# We have also used hyperparameter tuning method for deciding best K value of 'n_neighbors' in designing a KNN classifier, deciding optimal number of features for logistic regression parameter tuning for xgboost and choosing the best parameter for ANN.

# %% [markdown]
# # **Applying Classification Model**

# %% [markdown]
# Applying Classification Modelling
# Here, I will apply Logistic Regression, KNN Classification, Decesion Tree, Random Forest and Naive Bayes algorithm to classify the dependent feature.
#
# Following steps are involved in the model building
#
#
#
# *  Identifying optimal k value for KNN classifier.
# *  Identifying optimal number of features for logistic regression.
# *  Fitting data into classification models.
# *  Evaluating the performance of the models.

# %%
#Importing the requres ML Librarires
from sklearn.model_selection import train_test_split
#I use model_selection.train_test_split from sklearn library to split the data into training and testing sets.
#I set test_size=0.25 and random_state=216021. It means I split the existing dataset into 75% for data training, 
#and 25% for data test

X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.25, random_state=216021)

# %% [markdown]
# **Optimal Value of K for KNN**

# %%
# Optimal Value of k and Accuracy Rate for Optimal k

error_rate = []
for i in range(1,40):
 knn = KNeighborsClassifier(n_neighbors=i)
 knn.fit(X_train,y_train)
 pred_i = knn.predict(X_test)
 error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# Minimum error:- 0.031914893617021274 at K = 2

# %% [markdown]
# **Optimal number of features for logistic regression**

# %%
from sklearn.feature_selection import RFECV
log=LogisticRegression(random_state=7)

min_features_to_select=1
rfecv=RFECV(estimator=log,step=1,cv=5,scoring="accuracy",min_features_to_select=min_features_to_select)
rfecv.fit(X_train,y_train)

print("Optimal number of features : %d" % rfecv.n_features_)

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(min_features_to_select,
               len(rfecv.grid_scores_)+min_features_to_select),
         rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 2
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)

# %%
rfetable=pd.DataFrame({"Feature":X_train.columns,"Support":rfecv.support_,"Ranking":rfecv.ranking_,}).sort_values(by="Ranking",ascending=False)
rfetable
# Out:
#       Feature  Support  Ranking
# 0  Last_Price    False        6
# 5        Inst    False        5
# 3         Pub    False        4
# 2         EPS    False        3
# 1         NAV    False        2
# 4     Paid_up     True        1
# 6    Category     True        1

# %% [markdown]
# Recurssive feature elimination suggests we can remove some columns to the optimal amount of 4. But we will not do that for further analysis.

# %% [markdown]
# # **Training the classification models**

# %%
#Appling Logistic Regression model on the training set
from sklearn.linear_model import LogisticRegression
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train, y_train)

#Appling KNeighbors classifier model on the training set

from sklearn.neighbors import KNeighborsClassifier
knn_cls = KNeighborsClassifier(n_neighbors=2)
knn_cls.fit(X_train, y_train)

#Appling Decision Tree classifier model on the training set

from sklearn.tree import DecisionTreeClassifier 
dec_tree_cls=DecisionTreeClassifier(random_state = 0) 
dec_tree_cls.fit(X_train,y_train)

#Appling Random Forest Regressor model on the training set

from sklearn.ensemble import RandomForestClassifier
random_forest_cls = RandomForestClassifier()
random_forest_cls.fit(X_train, y_train)

#Appling Naive Bayes classifier model on the training set

from sklearn.naive_bayes import GaussianNB  
naive_bayes_cls = GaussianNB()
naive_bayes_cls.fit(X_train, y_train)

#Appling Support Vector Machine classifier model on the training set

from sklearn.svm import SVC
svc_cls = SVC()
svc_cls.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# # **Evaluating the models**

# %%
from sklearn.metrics import mean_squared_error, f1_score
def rmse_score(model, X_train, X_test, y_train, y_test):
    mse_train = mean_squared_error(y_true = y_train,
                                  y_pred = model.predict(X_train))
    mse_test = mean_squared_error(y_true = y_test,
                                  y_pred = model.predict(X_test))
    rmse_train = mse_train ** 0.5
    rmse_test = mse_test ** 0.5
    
    print("The training RMSE for " + str(model) + " is: " + str(rmse_train))
    print("The testing RMSE for " + str(model) + " is: " + str(rmse_test))
    return (rmse_train, rmse_test)

# %%
from sklearn.metrics import mean_squared_error, f1_score
def rmse_score(model, X_train, X_test, y_train, y_test):
    mse_train = mean_squared_error(y_true = y_train,
                                  y_pred = model.predict(X_train))
    mse_test = mean_squared_error(y_true = y_test,
                                  y_pred = model.predict(X_test))
    rmse_train = mse_train ** 0.5
    rmse_test = mse_test ** 0.5
    
    print("The training RMSE for " + str(model) + " is: " + str(rmse_train))
    print("The testing RMSE for " + str(model) + " is: " + str(rmse_test))
    return (rmse_train, rmse_test)
def cm(predictions):
    cm_matrix=pd.DataFrame(data=confusion_matrix(y_test,predictions),columns=['A', 'N', 'B', 'Z'],
                           index=['A', 'N', 'B', 'Z'])
    sns.heatmap(cm_matrix,annot=True,square=True,fmt="d",cmap="Purples",linecolor="w",linewidth=2)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.yticks(va="center")

# %% [markdown]
# **Logistic Regression**

# %%
x1,y1 = rmse_score(logistic_reg, X_train, X_test, y_train, y_test)
# Out:
# The training RMSE for LogisticRegression() is: 0.08451542547285165
# The testing RMSE for LogisticRegression() is: 0.10314212462587934

# %%
y_predict=logistic_reg.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       0.94      1.00      0.97        16
#            2       1.00      0.67      0.80         3
#            3       1.00      1.00      1.00         5
#
#     accuracy                           0.99        94
#    macro avg       0.99      0.92      0.94        94
# weighted avg       0.99      0.99      0.99        94

# %%
cm_log=cm(y_predict)
cm_log

# %%
print("Training set Accuracy score: {num:.4f}.".format(num=logistic_reg.score(X_train,y_train)))
print("Testing set Accuracy score: {num:.4f}.".format(num=logistic_reg.score(X_test,y_test)))
# Out:
# Training set Accuracy score: 0.9929.
# Testing set Accuracy score: 0.9894.

# %% [markdown]
# **KNN Classifier**

# %%
x2,y2= rmse_score(knn_cls, X_train, X_test, y_train, y_test)
# Out:
# The training RMSE for KNeighborsClassifier(n_neighbors=2) is: 0.1889822365046136
# The testing RMSE for KNeighborsClassifier(n_neighbors=2) is: 0.309426373877638

# %%
y_predict=knn_cls.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97        70
#            1       0.92      0.69      0.79        16
#            2       1.00      1.00      1.00         3
#            3       1.00      0.80      0.89         5
#
#     accuracy                           0.94        94
#    macro avg       0.96      0.87      0.91        94
# weighted avg       0.94      0.94      0.93        94

# %%
cm_knn=cm(y_predict)
cm_knn

# %%
print("Training set Accuracy score: {num:.4f}.".format(num=knn_cls.score(X_train,y_train)))
print("Testing set Accuracy score: {num:.4f}.".format(num=knn_cls.score(X_test,y_test)))
# Out:
# Training set Accuracy score: 0.9643.
# Testing set Accuracy score: 0.9362.

# %% [markdown]
# **Decision Tree Classifier**

# %%
x3,y3= rmse_score(dec_tree_cls, X_train, X_test, y_train, y_test)
# Out:
# The training RMSE for DecisionTreeClassifier(random_state=0) is: 0.0
# The testing RMSE for DecisionTreeClassifier(random_state=0) is: 0.0

# %%
y_predict=dec_tree_cls.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         5
#
#     accuracy                           1.00        94
#    macro avg       1.00      1.00      1.00        94
# weighted avg       1.00      1.00      1.00        94

# %%
cm_dt=cm(y_predict)
cm_dt

# %%
print("Training set Accuracy score: {num:.4f}.".format(num=dec_tree_cls.score(X_train,y_train)))
print("Testing set Accuracy score: {num:.4f}.".format(num=dec_tree_cls.score(X_test,y_test)))
# Out:
# Training set Accuracy score: 1.0000.
# Testing set Accuracy score: 1.0000.

# %% [markdown]
# **Random Forest Classifier**

# %%
x4, y4= rmse_score(random_forest_cls, X_train, X_test, y_train, y_test)
# Out:
# The training RMSE for RandomForestClassifier() is: 0.0
# The testing RMSE for RandomForestClassifier() is: 0.0

# %%
y_predict=random_forest_cls.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         5
#
#     accuracy                           1.00        94
#    macro avg       1.00      1.00      1.00        94
# weighted avg       1.00      1.00      1.00        94

# %%
cm_rm=cm(y_predict)
cm_rm

# %%
print("Training set Accuracy score: {num:.4f}.".format(num=random_forest_cls.score(X_train,y_train)))
print("Testing set Accuracy score: {num:.4f}.".format(num=random_forest_cls.score(X_test,y_test)))
# Out:
# Training set Accuracy score: 1.0000.
# Testing set Accuracy score: 1.0000.

# %% [markdown]
# **Naive Bayes classifier**

# %%
x5, y5= rmse_score(naive_bayes_cls, X_train, X_test, y_train, y_test)
# Out:
# The training RMSE for GaussianNB() is: 0.0
# The testing RMSE for GaussianNB() is: 0.0

# %%
y_predict=naive_bayes_cls.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         5
#
#     accuracy                           1.00        94
#    macro avg       1.00      1.00      1.00        94
# weighted avg       1.00      1.00      1.00        94

# %%
cm_bayes=cm(y_predict)
cm_bayes

# %%
print("Training set Accuracy score: {num:.4f}.".format(num=naive_bayes_cls.score(X_train,y_train)))
print("Testing set Accuracy score: {num:.4f}.".format(num=naive_bayes_cls.score(X_test,y_test)))
# Out:
# Training set Accuracy score: 1.0000.
# Testing set Accuracy score: 1.0000.

# %% [markdown]
# **support vector machine classifier**

# %%
x6, y6= rmse_score(svc_cls, X_train, X_test, y_train, y_test)
# Out:
# The training RMSE for SVC() is: 0.05976143046671968
# The testing RMSE for SVC() is: 0.3261640365267211

# %%
y_predict=svc_cls.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        70
#            1       1.00      0.94      0.97        16
#            2       1.00      1.00      1.00         3
#            3       1.00      0.80      0.89         5
#
#     accuracy                           0.98        94
#    macro avg       0.99      0.93      0.96        94
# weighted avg       0.98      0.98      0.98        94

# %%
cm_bayes=cm(y_predict)
cm_bayes

# %%
print("Training set Accuracy score: {num:.4f}.".format(num=svc_cls.score(X_train,y_train)))
print("Testing set Accuracy score: {num:.4f}.".format(num=svc_cls.score(X_test,y_test)))
# Out:
# Training set Accuracy score: 0.9964.
# Testing set Accuracy score: 0.9787.

# %% [markdown]
# # **Plotting the Results**

# %%
X = ['log_reg','knn','dtree','rforest','naive_bayes', 'svc' ]
train = [x1,x2,x3,x4,x5,x6]
test = [y1,y2,y3,y4,y5,y6]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, train, 0.4, label = 'training rmse')
plt.bar(X_axis + 0.2, test, 0.4, label = 'testing rsme')
  
plt.xticks(X_axis, X)
plt.xlabel("Classification Models")
plt.ylabel("RSME Values")
plt.title("Comparison of Classification models")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# %% [markdown]
# # **Parallel Ensemble Learning**
# **Bagging methods**

# %%
# Pipeline Estimator
pipeline = make_pipeline(StandardScaler(), LogisticRegression(random_state=1))
# Fit the model
pipeline.fit(X_train, y_train)
# Model scores on test and training data
print('Model test Score: %.3f, ' %pipeline.score(X_test, y_test),
'Model training Score: %.3f' %pipeline.score(X_train, y_train))

# Model fit using Bagging Classifier
# Pipeline Estimator
pipeline = make_pipeline(StandardScaler(),
LogisticRegression(random_state=1))
# Instantiate the bagging classifier
bgclassifier = BaggingClassifier(base_estimator=pipeline,
n_estimators=100,
max_features=6,
max_samples=100,
random_state=1, n_jobs=5)
# Fit the bagging classifier
bgclassifier.fit(X_train, y_train)
# Model scores on test and training data
print('Model test Score: %.3f, ' %bgclassifier.score(X_test,
y_test),
'Model training Score: %.3f' %bgclassifier.score(X_train,
y_train))
# Out:
# Model test Score: 0.989,  Model training Score: 0.993
# Model test Score: 0.968,  Model training Score: 0.968

# %%
# Predicting the test set results
y_pred = bgclassifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
print('Model Accuracy Score: %.3f, ' %accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy Score: 0.894,

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        70
#            1       0.64      0.88      0.74        16
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.89        94
#    macro avg       0.40      0.47      0.43        94
# weighted avg       0.83      0.89      0.86        94
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # **Sequential Ensemble Learning**
# **Boosting Methods**

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV

def random_search_tuning():
    params = {'max_depth': [3, 6, 10, 15],
              'learning_rate': [0.01, 0.1, 0.2, 0.3, 0.4],
              'subsample': np.arange(0.5, 1.0, 0.1),
              'colsample_bytree': np.arange(0.5, 1.0, 0.1),
              'colsample_bylevel': np.arange(0.5, 1.0, 0.1),
              'n_estimators': [100, 250, 500, 750],
              'num_class': [10]
              }

    xgbclf = xgb.XGBClassifier(objective="multi:softmax", tree_method='hist')
    clf = RandomizedSearchCV(estimator=xgbclf,
                             param_distributions=params,
                             scoring='accuracy',
                             n_iter=25,
                             n_jobs=4,
                             verbose=1)

    clf.fit(X_train, y_train)

    best_combination = clf.best_params_

    return best_combination

if __name__ == '__main__':

    best_params = random_search_tuning()

    print("Best hyperparameter combination: ", best_params)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# Best hyperparameter combination:  {'subsample': 0.5, 'num_class': 10, 'n_estimators': 750, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.7999999999999999, 'colsample_bylevel': 0.5}

# %%
params = {'max_depth': [3],
              'learning_rate': [0.2],
              'subsample': [0.5],
              'colsample_bytree': [0.7999999999999999],
              'colsample_bylevel': [0.5] ,
              'n_estimators':  [750],
              'num_class': [10]
              }

xgbclf = xgb.XGBClassifier(objective="multi:softmax", tree_method='hist')
clf = RandomizedSearchCV(estimator=xgbclf,
                             param_distributions=params,
                             scoring='accuracy',
                             n_iter=25,
                             n_jobs=4,
                             verbose=1)
from sklearn.metrics import accuracy_score
     
# Train Adaboost Classifer
model = clf.fit(X_train, y_train)
#Predict the response for test dataset
y_pred = model.predict(X_test)
# Model scores on test and training data
print('Model test Score: %.3f, ' %bgclassifier.score(X_test,
y_test),
'Model training Score: %.3f' %bgclassifier.score(X_train,
y_train))
print('Model Accuracy Score: %.3f, ' %accuracy_score(y_test, model.predict(X_test)))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:296: UserWarning: The total space of parameters 1 is smaller than n_iter=25. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   UserWarning,
# Model test Score: 0.968,  Model training Score: 0.968
# Model Accuracy Score: 1.000,

# %%
y_predict=model.predict(X_test)
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        70
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         5
#
#     accuracy                           1.00        94
#    macro avg       1.00      1.00      1.00        94
# weighted avg       1.00      1.00      1.00        94

# %%
xg_boost=cm(y_predict)
xg_boost

# %% [markdown]
# # **ANN MODEL BUILDING**
# In this project, we build an artificial neural network.
#
# Following steps are involved in the model building
#
#
#
# *   Initialising the neural network
# *   Defining by adding layers
# *   Compiling the neural network
# *   Train the neural network

# %%
#Early stopping
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True,
)

# Initialising the NN
model = Sequential()

# layers

model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu', input_dim = 7))
model.add(Dense(units = 32, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
opt = Adam(learning_rate=0.00009)
model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = 32, epochs = 150, callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/150
# 7/7 [==============================] - 1s 46ms/step - loss: 0.6931 - accuracy: 0.2545 - val_loss: 0.6932 - val_accuracy: 0.1429
# Epoch 2/150
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.1607 - val_loss: 0.6932 - val_accuracy: 0.1429
# Epoch 3/150
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.1607 - val_loss: 0.6932 - val_accuracy: 0.1429
# Epoch 4/150
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.1607 - val_loss: 0.6932 - val_accuracy: 0.1429
# Epoch 5/150
# 7/7 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.1607 - val_loss: 0.6933 - val_accuracy: 0.1429
# Epoch 6/150
# 7/7 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.1607 - val_loss: 0.6933 - val_accuracy: 0.1429
# Epoch 7/150
# ...

# %% [markdown]
# Plotting training and validation loss over epochs

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#BDE2E2", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#C2C4E2", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# Plotting training and validation accuracy over epochs

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#BDE2E2", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#C2C4E2", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# CONCLUSIONS
#
# Concluding the model with:
#
#
#
# *   Testing on the test set
# *   Evaluating the confusion matrix
# *   Evaluating the classification reportList item

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 3/3 [==============================] - 0s 5ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(260,-10,s=50, l=75, n=5, as_cmap=True)
plt.subplots(figsize=(12,8))
cf_matrix=pd.DataFrame(data=confusion_matrix(y_test,y_pred),columns=['A', 'N', 'B', 'Z'],index=['A', 'N', 'B', 'Z'])
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})

# %%
print('Model Accuracy Score: %.3f, ' %accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy Score: 0.170,

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        70
#            1       0.17      1.00      0.29        16
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00         5
#
#     accuracy                           0.17        94
#    macro avg       0.04      0.25      0.07        94
# weighted avg       0.03      0.17      0.05        94
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# # **Classification Model Evaluation Table**

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# # **4. Discussion**#

# %% [markdown]
# From the analysis of the Precision,	Recall, Score,
# RMSE scores, Accuracy of the above classification models, it can be clearly stated that the
# Decision Tree,Naive Bayes, Random Forest and Sequential Ensemble Learning (XG-Boosting) models has high accuracy. But Naive Bayes along with Support Vector Machine overfit the training dataset, and hence are to be discarded for this
# problem. From the model Logistics Regression and Naive Bayes, it is visible that the RMSE score for test
# data is higher than the Decision Tree, Random Forest, Sequential Ensemble Learning (XG-Boosting). So, the Decision Tree, Random Forest, Sequential Ensemble Learning (XG-Boosting) have the highest prediction accuracy for this
# problem

# %% [markdown]
# # **5.Conclusions**

# %% [markdown]
# Automating stock market forecasting has always been an attractive and challenging idea. At least since the advent of artificial intelligence, it has been clear that artificial intelligence is suitable for such complex predictions.
#
# Most trading today is done through bots and is based on calculations by machine learning algorithms. Deep learning neural networks. In this report I have tried fit some of the machine learning and artificial neural networks such as DT, KNN, Rando Forest, XG Boost which are widely used in stock trading models due to their higher capacity and efficiency compared to linear algorithms.
#
# However, it remains questionable whether such algorithms are really effective. The stock market is notoriously volatile, so developing a practical ML algorithm requires a lot of effort.

# %% [markdown]
# # **6. References**

# %% [markdown]
# 1.   What is 'Stock Market', The Economic Times
#
# 2.   What is 'Categories' , The Economic Times
#
# 3. Machine Learning Algorithms for Stock Market: Make It Work for You, labelyourdata.com
#
# 4. SaminaHaque, Murtaza Faruquee, Impact of Fundamental Factors on Stock Price: A Case Based Approach on Pharmaceutical Companies Listed with Dhaka Stock Exchange,International Journal of Business and Management Invention, ISSN (Online): 2319 – 8028, ISSN (Print): 2319 – 801X, Volume 2 Issue 9, September 2013
#
# 5. Abdullah M. N., Parvez K. and Khaled M., Is the Stock Market Overvalued: A Study in the Context of Bangladesh? Asian Business Review, Vol. 1, Issue 1, 2012, 30-36.
#
# 6. Chowdhury A. and Abdullah M.N., Overheated Stock Market: Remidial Measures for Soft Landing, Journal of Institute of Cost & Management Accounts of Bangladesh, Vol. 5, 2011, 28.
#
# 7. Chowdhury R. A. and Chowdhury S.P., Impact of Capital Structure on Firm’s Value: Evidence from Bangladesh, Business and Economic Horizon, 3 (3), 2010, 111-122.
#
# 8. Chen J., Hong H. and Stein J.C., Breadth of Ownership and Stock Return, Journal of Financial Economics, Vol. 66, 2002, 171-205.
#
# 9. Random forest, Naive Bayes classifier,Decision Tree and Sequential Ensemble Learning (XG-Boosting), https://en.wikipedia.org/
#
# 10. Artificial Neural Network, https://www.sciencedirect.com/topics/earth-and-planetary-sciences/artificial-neural-network
